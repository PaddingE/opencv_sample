# %%
import sys
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
src = cv2.imread('./fig_ch3/lenna.bmp', cv2.IMREAD_COLOR)

# dst = np.clip(src + 100., 0, 255).astype(np.uint8)
dst = cv2.add(src,(100,100,100,0))

cv2.imshow('src', src)
cv2.imshow('dst', dst)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
src1 = cv2.imread('./fig_ch3/lenna256.bmp', 0)
src2 = np.zeros_like(src1)
cv2.circle(src2, (128,128), 100, 200, -1, cv2.LINE_AA)
cv2.circle(src2, (128,128), 50, 50, -1, cv2.LINE_AA)


dst1 = cv2.add(src1, src2)
dst2 = cv2.addWeighted(src1, 0.5, src2, 0.5, 0)
dst3 = cv2.subtract(src1, src2)
dst4 = cv2.absdiff(src1, src2)


fig, ax = plt.subplots(2,3,figsize = (12,6))

ax[0,0].imshow(src1, cmap = 'gray'), ax[0,0].axis('off'), ax[0,0].set_title('src1')
ax[0,1].imshow(src2, cmap = 'gray'), ax[0,1].axis('off'), ax[0,1].set_title('src2')
ax[0,2].imshow(dst1, cmap = 'gray'), ax[0,2].axis('off'), ax[0,2].set_title('add')
ax[1,0].imshow(dst2, cmap = 'gray'), ax[1,0].axis('off'), ax[1,0].set_title('addweight')
ax[1,1].imshow(dst3, cmap = 'gray'), ax[1,1].axis('off'), ax[1,1].set_title('subtract')
ax[1,2].imshow(dst4, cmap = 'gray'), ax[1,2].axis('off'), ax[1,2].set_title('absdiff')

# cv2.imshow('src', src1)
# cv2.imshow('src2', src2)
# cv2.imshow('dst1', dst1)
# cv2.imshow('dst2', dst2)
# cv2.imshow('dst3', dst3)
# cv2.imshow('dst4', dst4)

# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# (<matplotlib.image.AxesImage at 0x20ff4edccd0>,
#  (-0.5, 255.5, 255.5, -0.5),
#  Text(0.5, 1.0, 'absdiff'))

# %%
src = cv2.imread('./fig/puppy.bmp', 0)
dst = cv2.imread('./copy_img.png', 0)
h,w = dst.shape[:2]
src = cv2.resize(src,(w,h),interpolation=cv2.INTER_AREA)
# src3 = cv2.addWeighted(src1, 1, src2, 0, 0)
# cv2.imshow('src1', src1)
# cv2.imshow('src2', src2)

for i in range(100):
    alpha = i*0.01
    src1 = cv2.addWeighted(src, 1-alpha, dst, alpha, 0)
    cv2.imshow('src1',src1)
    
    if cv2.waitKey(50) == 27:
        break
    
cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread('./fig_ch3/flowers.jpg')
src_hsv = cv2.cvtColor(src,cv2.COLOR_BGR2HSV)
h,s,v = cv2.split(src_hsv)
b,g,r = cv2.split(src)
# blue = src[:,:,0]
# green = src[:,:,1]
# red = src[:,:,2]
b_add = b + 50

# dst = cv2.merge((b_add, g, r))

cv2.imshow('img', src)
cv2.imshow('blue', b)
cv2.imshow('green', g)
cv2.imshow('red', r)
# cv2.imshow('dst', dst)
cv2.imshow('h', h)
cv2.imshow('s', s)
cv2.imshow('v', v)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread('./fig_ch3/lenna.bmp',1)

hist_b = cv2.calcHist([src], [0],None, [256], [0,256])
hist_g = cv2.calcHist([src], [1],None, [256], [0,256])
hist_r = cv2.calcHist([src], [2],None, [256], [0,256])

cv2.imshow('src', src)

cv2.waitKey()
cv2.destroyAllWindows()

plt.figure(figsize=(4,2))
plt.plot(hist_b, 'b')
plt.plot(hist_g, 'g')
plt.plot(hist_r, 'r')
plt.show()
